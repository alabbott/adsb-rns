# %%
from proto import *

MAGIC
# Out:
# b'\xad\xb5'

# %%
aircraft = fetch_aircraft('https://adsb.alabbott.dev/data/aircraft.json')

aircraft
# Out:
# [{'hex': 'a72b40',
#   'type': 'mlat',
#   'r': 'N561GJ',
#   't': 'CRJ7',
#   'desc': 'BOMBARDIER Regional Jet CRJ-700',
#   'ownOp': 'UNITED AIRLINES INC',
#   'year': '2002',
#   'alt_baro': 21650,
#   'alt_geom': 21475,
#   'gs': 390.9,
#   'track': 201.77,
#   'baro_rate': 2752,
#   'geom_rate': 2240,
#   'lat': 41.388477,
#   'lon': -88.186873,
#   'nic': 0,
#   'rc': 0,
#   'seen_pos': 38.929,
#   'r_dst': 38.928,
#   'r_dir': 217.2,
#   'version': 0,
#   'nac_v': 0,
#   'alert': 1,
#   'spi': 0,
#   'mlat': ['baro_rate', 'lat', 'lon', 'nic', 'rc', 'nac_v'],
#   'tisb': [],
#   'messages': 107,
#   'seen': 38.9,
#   'rssi': -26.7},
#  {'hex': 'a1ac11',
#   'type': 'adsb_icao',
#   'r': 'N207AN',
#   't': 'E75L',
#   'desc': 'EMBRAER ERJ-170-200 (long wing)',
#   'ownOp': 'AMERICAN AIRLINES INC',
#   'year': '2015',
#   'alt_baro': 27475,
#   'alt_geom': 27175,
#   'gs': 339.6,
#   'track': 322.66,
#   'baro_rate': -1024,
#   'lat': 41.507186,
#   'lon': -88.105689,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 41.504,
#   'r_dst': 31.058,
#   'r_dir': 219.6,
#   'version': 0,
#   'nac_p': 8,
#   'nac_v': 2,
#   'sil': 2,
#   'sil_type': 'unknown',
#   'alert': 0,
#   'spi': 0,
#   'mlat': [],
#   'tisb': [],
#   'messages': 59,
#   'seen': 32.6,
#   'rssi': -26.0},
#  {'hex': 'a1bee0',
#   'type': 'adsb_icao',
#   'flight': 'SKW6051 ',
#   'r': 'N211SY',
#   't': 'E75L',
#   'desc': 'EMBRAER ERJ-170-200 (long wing)',
#   'ownOp': 'SKYWEST AIRLINES INC',
#   'year': '2017',
#   'alt_baro': 11350,
#   'alt_geom': 11325,
#   'gs': 324.7,
#   'track': 154.07,
#   'baro_rate': 2880,
#   'squawk': '6254',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1020.8,
#   'nav_altitude_mcp': 23008,
#   'nav_modes': ['autopilot', 'vnav', 'tcas'],
#   'lat': 41.709083,
#   'lon': -87.808036,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 28.332,
#   'r_dst': 13.476,
#   'r_dir': 208.4,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'alert': 0,
#   'spi': 0,
#   'mlat': [],
#   'tisb': [],
#   'messages': 517,
#   'seen': 1.5,
#   'rssi': -22.6},
#  {'hex': 'a9ab87',
#   'type': 'adsb_icao',
#   'flight': 'FFT2800 ',
#   'r': 'N722FR',
#   't': 'A321',
#   'desc': 'AIRBUS A-321',
#   'ownOp': 'ALC A321 8579 LLC',
#   'year': '2018',
#   'alt_baro': 5750,
#   'alt_geom': 5800,
#   'gs': 216.0,
#   'track': 89.73,
#   'baro_rate': -1472,
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1020.8,
#   'nav_altitude_mcp': 4992,
#   'lat': 41.884277,
#   'lon': -87.798302,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 1.166,
#   'r_dst': 6.096,
#   'r_dir': 257.4,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 3,
#   'alert': 0,
#   'spi': 0,
#   'mlat': [],
#   'tisb': [],
#   'messages': 95,
#   'seen': 0.6,
#   'rssi': -23.0},
#  {'hex': 'a7e1cd',
#   'type': 'adsb_icao',
#   'flight': 'FFT2791 ',
#   'r': 'N607FR',
#   't': 'A21N',
#   'desc': 'AIRBUS A-321neo',
#   'ownOp': 'BANK OF UTAH TRUSTEE',
#   'year': '2022',
#   'alt_baro': 2675,
#   'alt_geom': 2750,
#   'gs': 146.0,
#   'track': 270.0,
#   'baro_rate': -832,
#   'squawk': '2064',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1020.8,
#   'nav_altitude_mcp': 4000,
#   'lat': 41.965897,
#   'lon': -87.742747,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 1.24,
#   'r_dst': 4.979,
#   'r_dir': 315.8,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 3,
#   'alert': 0,
#   'spi': 0,
#   'mlat': [],
#   'tisb': [],
#   'messages': 2480,
#   'seen': 1.2,
#   'rssi': -19.0},
#  {'hex': 'a2b198',
#   'type': 'adsb_icao',
#   'flight': 'UAL366  ',
#   'r': 'N27292',
#   't': 'B38M',
#   'desc': 'BOEING 737 MAX 8',
#   'ownOp': 'UMB BANK NA TRUSTEE',
#   'year': '2023',
#   'alt_baro': 3800,
#   'alt_geom': 3850,
#   'gs': 161.0,
#   'track': 270.36,
#   'baro_rate': 0,
#   'squawk': '2727',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1020.8,
#   'nav_altitude_mcp': 4000,
#   'nav_heading': 272.81,
#   'lat': 41.965911,
#   'lon': -87.630658,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 4.142,
#   'r_dst': 3.885,
#   'r_dir': 23.2,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'alert': 0,
#   'spi': 0,
#   'mlat': [],
#   'tisb': [],
#   'messages': 518,
#   'seen': 1.9,
#   'rssi': -16.2},
#  {'hex': 'aa42aa',
#   'type': 'adsb_icao',
#   'flight': 'ENY9873 ',
#   'r': 'N760MQ',
#   't': 'E170',
#   'desc': 'EMBRAER ERJ-170-100',
#   'ownOp': 'WILMINGTON TRUST CO TRUSTEE',
#   'year': '2009',
#   'alt_baro': 5925,
#   'alt_geom': 5975,
#   'gs': 208.2,
#   'track': 351.71,
#   'baro_rate': -1728,
#   'squawk': '4033',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1020.8,
#   'nav_altitude_mcp': 5024,
#   'nav_modes': ['autopilot', 'tcas'],
#   'lat': 41.803118,
#   'lon': -87.533633,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.098,
#   'r_dst': 8.538,
#   'r_dir': 136.5,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'alert': 0,
#   'spi': 0,
#   'mlat': [],
#   'tisb': [],
#   'messages': 558,
#   'seen': 0.0,
#   'rssi': -20.4},
#  {'hex': 'a3f133',
#   'type': 'adsb_icao',
#   'flight': 'DAL8927 ',
#   'r': 'N353NW',
#   't': 'A320',
#   'desc': 'AIRBUS A-320',
#   'ownOp': 'DELTA AIR LINES INC',
#   'year': '1998',
#   'alt_baro': 37975,
#   'alt_geom': 37625,
#   'gs': 404.8,
#   'track': 323.64,
#   'baro_rate': 384,
#   'squawk': '6701',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 38016,
#   'nav_heading': 0.0,
#   'lat': 41.690552,
#   'lon': -87.50317,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.42,
#   'r_dst': 14.853,
#   'r_dir': 150.8,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'alert': 0,
#   'spi': 0,
#   'mlat': [],
#   'tisb': [],
#   'messages': 2257,
#   'seen': 0.3,
#   'rssi': -9.5},
#  {'hex': 'a9d3f9',
#   'type': 'mode_s',
#   'flight': 'N732RJ  ',
#   'r': 'N732RJ',
#   't': 'LJ60',
#   'desc': 'LEARJET 60',
#   'ownOp': 'N732RJ LLC',
#   'year': '2011',
#   'category': 'A6',
#   'version': 0,
#   'nac_p': 8,
#   'sil': 2,
#   'sil_type': 'unknown',
#   'alert': 0,
#   'spi': 0,
#   'mlat': [],
#   'tisb': [],
#   'messages': 7,
#   'seen': 0.6,
#   'rssi': -26.2}]

# %%
# first aircraft
ac = aircraft[0]

get_dist(ac.get('lat'), ac.get('lon'), 41.90, -87.66)
# Out:
# 38.672939734932044

# %%
bearing_to(ac.get('lat'), ac.get('lon'), 41.90, -87.66)
# Out:
# 217.47547579283741

# %%
vrate_symbol(ac.get('vr'))
# Out:
# '→'

# %%
print(ac.get('lat'))
encoded_deg = encode_degs(ac.get('lat'))
print(encoded_deg)
decoded = encoded_deg / 200.0
print(decoded)
# Out:
# 41.388477
# 8278
# 41.39

# %%
print(len(aircraft))
# Out:
# 9

# %%
filtered = filter_aircraft(aircraft, range_nm=3)
print(len(filtered))
# Out:
# 1

# %%
filtered[0]
# Out:
# {'hex': 'a2b198',
#  'type': 'adsb_icao',
#  'flight': 'UAL366  ',
#  'r': 'N27292',
#  't': 'B38M',
#  'desc': 'BOEING 737 MAX 8',
#  'ownOp': 'UMB BANK NA TRUSTEE',
#  'year': '2023',
#  'alt_baro': 3800,
#  'alt_geom': 3850,
#  'gs': 161.0,
#  'track': 270.36,
#  'baro_rate': 0,
#  'squawk': '2727',
#  'emergency': 'none',
#  'category': 'A3',
#  'nav_qnh': 1020.8,
#  'nav_altitude_mcp': 4000,
#  'nav_heading': 272.81,
#  'lat': 41.965911,
#  'lon': -87.630658,
#  'nic': 8,
#  'rc': 186,
#  'seen_pos': 4.142,
#  'r_dst': 3.885,
#  'r_dir': 23.2,
#  'version': 2,
#  'nic_baro': 1,
#  'nac_p': 10,
#  'nac_v': 2,
#  'sil': 3,
#  'sil_type': 'perhour',
#  'gva': 2,
#  'sda': 2,
#  'alert': 0,
#  'spi': 0,
#  'mlat': [],
#  'tisb': [],
#  'messages': 518,
#  'seen': 1.9,
#  'rssi': -16.2}

# %%
encode_frame(filtered)
# Out:
# b'\xad\xb5\x04i\xd34\x1a\x01 \xc2\xbb\x84\xa2\xb1\x98 \xc9\xbb\x8a\x01|\x87P\x00\x1f\x06UAL366'

# %%
frame = encode_frame(filtered)
frame
# Out:
# b'\xad\xb5\x04i\xd34\x1a\x01 \xc2\xbb\x84\xa2\xb1\x98 \xc9\xbb\x8a\x01|\x87P\x00\x1f\x06UAL366'

# %%
for c in frame:
    print(hex(c))
# Out:
# 0xad
# 0xb5
# 0x4
# 0x69
# 0xd3
# 0x34
# 0x1a
# 0x1
# 0x20
# 0xc2
# 0xbb
# 0x84
# 0xa2
# 0xb1
# 0x98
# 0x20
# 0xc9
# 0xbb
# 0x8a
# 0x1
# 0x7c
# 0x87
# 0x50
# 0x0
# 0x1f
# 0x6
# 0x55
# 0x41
# 0x4c
# 0x33
# 0x36
# 0x36

# %%
decoded_frame = decode_frame(frame)
decoded_frame
# Out:
# {'timestamp': 1775449114,
#  'aircraft': [{'icao': 'A2B198',
#    'hex': 'a2b198',
#    'lat': 41.965,
#    'lon': -87.63,
#    'alt_baro': 3800,
#    'track': 270,
#    'gs': 160,
#    'baro_rate': 0,
#    'flight': '�� ���\x01|�P\x00\x1f\x06UAL366',
#    'sender_dist': 2.5,
#    'sender_brg': 33,
#    'flags': 31,
#    'gs_ovf': False,
#    'vr_ovf': False,
#    'emrg': False}],
#  'sender_center': (41.93, -87.66)}

# %%
filtered[0]
# Out:
# {'hex': 'a2b198',
#  'type': 'adsb_icao',
#  'flight': 'UAL366  ',
#  'r': 'N27292',
#  't': 'B38M',
#  'desc': 'BOEING 737 MAX 8',
#  'ownOp': 'UMB BANK NA TRUSTEE',
#  'year': '2023',
#  'alt_baro': 3800,
#  'alt_geom': 3850,
#  'gs': 161.0,
#  'track': 270.36,
#  'baro_rate': 0,
#  'squawk': '2727',
#  'emergency': 'none',
#  'category': 'A3',
#  'nav_qnh': 1020.8,
#  'nav_altitude_mcp': 4000,
#  'nav_heading': 272.81,
#  'lat': 41.965911,
#  'lon': -87.630658,
#  'nic': 8,
#  'rc': 186,
#  'seen_pos': 4.142,
#  'r_dst': 3.885,
#  'r_dir': 23.2,
#  'version': 2,
#  'nic_baro': 1,
#  'nac_p': 10,
#  'nac_v': 2,
#  'sil': 3,
#  'sil_type': 'perhour',
#  'gva': 2,
#  'sda': 2,
#  'alert': 0,
#  'spi': 0,
#  'mlat': [],
#  'tisb': [],
#  'messages': 518,
#  'seen': 1.9,
#  'rssi': -16.2}

# %%
decoded_frame['aircraft'][0]
# Out:
# {'icao': 'A2B198',
#  'hex': 'a2b198',
#  'lat': 41.965,
#  'lon': -87.63,
#  'alt_baro': 3800,
#  'track': 270,
#  'gs': 160,
#  'baro_rate': 0,
#  'flight': '�� ���\x01|�P\x00\x1f\x06UAL366',
#  'sender_dist': 2.5,
#  'sender_brg': 33,
#  'flags': 31,
#  'gs_ovf': False,
#  'vr_ovf': False,
#  'emrg': False}
